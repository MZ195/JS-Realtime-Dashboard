# %%
from pandas import read_csv, DataFrame
from datetime import datetime
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
series = read_csv('./Data/Processed_BT_PriceDB.csv', header=0, parse_dates=[0], index_col=0, squeeze=True)
print(series.head())
series.plot()
pyplot.show()
# Out:
# new_time
# 2021-06-25 15:47:00+03:00    33846.4567
# 2021-06-25 15:47:30+03:00    33916.1856
# 2021-06-25 15:48:00+03:00    33866.0833
# 2021-06-25 15:48:30+03:00    33866.0833
# 2021-06-25 15:49:00+03:00    33836.3497
# Name: avg, dtype: float64

# %%
series = read_csv('./Data/Processed_BT_PriceDB.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
# series.index = series.index.to_period('M')
# split into train and test sets
X = series.values
size = int(len(X) * 0.8)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()

# %% [markdown]
# ## WARNING: this code took me 15 min to run!

# %%
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)

# walk-forward validation
for t in range(len(test)):
    model = ARIMA(history, order=(1,1,3))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    print(yhat)
    predictions.append(yhat)
    obs = test[t]
    history.append(obs) # add the actual value back in the model

# %%
print(len(predictions))
print(len(test))

# # evaluate forecasts
# rmse = sqrt(mean_squared_error(test, predictions))
# print('Test RMSE: %.3f' % rmse)
# # plot forecasts against actual outcomes
# pyplot.plot(test)
# pyplot.plot(predictions, color='red')
# pyplot.show()
# Out:
# 806
# 197
